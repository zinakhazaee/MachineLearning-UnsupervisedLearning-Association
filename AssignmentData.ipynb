# %% [markdown]
# <a href="https://colab.research.google.com/github/zinakhazaee/MachineLearning-UnsupervisedLearning-Association/blob/main/AssignmentData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
df = pd.read_excel('/content/drive/MyDrive/datasets_sample/market-basket-analysis/AssignmentData.xlsx')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    BillNo                             Itemname  Quantity                Date  \
# 0  536365   WHITE HANGING HEART T-LIGHT HOLDER         6 2010-12-01 08:26:00
# 1  536365                  WHITE METAL LANTERN         6 2010-12-01 08:26:00
# 2  536365       CREAM CUPID HEARTS COAT HANGER         8 2010-12-01 08:26:00
# 3  536365  KNITTED UNION FLAG HOT WATER BOTTLE         6 2010-12-01 08:26:00
# 4  536365       RED WOOLLY HOTTIE WHITE HEART.         6 2010-12-01 08:26:00
#
#    Price  CustomerID         Country
# 0   2.55     17850.0  United Kingdom
# 1   3.39     17850.0  United Kingdom
# 2   2.75     17850.0  United Kingdom
# 3   3.39     17850.0  United Kingdom
# 4   3.39     17850.0  United Kingdom

# %%
df.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (522064, 7)

# %%
df.groupby('Country').size()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Country
# Australia                 1185
# Austria                    398
# Bahrain                     18
# Belgium                   2031
# Brazil                      32
# France                    8408
# Germany                   9042
# Greece                     145
# Hong Kong                  284
# Iceland                    182
# Israel                     295
# Italy                      758
# Japan                      321
# Lebanon                     45
# Lithuania                   35
# Malta                      112
# Netherlands               2363
# Norway                    1072
# Poland                     330
# Portugal                  1501
# RSA                         58
# Saudi Arabia                 9
# Singapore                  222
# Spain                     2485
# Sweden                     451
# Switzerland               1967
# USA                        179
# United Arab Emirates        68
# United Kingdom          487622
# Unspecified                446
# dtype: int64

# %%
basket_Germany = (df[df['Country']=='Germany'].groupby(['BillNo','Itemname'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('BillNo')
          )
basket_United_Kingdom = (df[df['Country']=='United Kingdom'].groupby(['BillNo','Itemname'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('BillNo')
          )
basket_France = (df[df['Country']=='France'].groupby(['BillNo','Itemname'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('BillNo')
          )
basket_Netherlands = (df[df['Country']=='Netherlands'].groupby(['BillNo','Itemname'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('BillNo')
          )
basket_Spain = (df[df['Country']=='Spain'].groupby(['BillNo','Itemname'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('BillNo')
          )
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
def encode_units(x):
  if x <= 0:
    return 0
  if x >= 1 :
    return 1
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ## Germany ,United Kingdom ,France ,Netherlands ,Spain

# %%
basket_set_Germany = basket_Germany.applymap(encode_units)
frequent_items_Germany = apriori(basket_set_Germany , min_support= 0.07 , use_colnames= True)
frequent_items_Germany.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/mlxtend/frequent_patterns/fpcommon.py:110: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#     support                     itemsets
# 0  0.102845     (6 RIBBONS RUSTIC CHARM)
# 1  0.070022  (ALARM CLOCK BAKELIKE PINK)
# 2  0.072210          (GUMBALL COAT RACK)
# 3  0.091904     (JAM MAKING SET PRINTED)
# 4  0.078775    (JUMBO BAG RED RETROSPOT)

# %%
basket_set_United_Kingdom = basket_United_Kingdom.applymap(encode_units)
frequent_items_United_Kingdom = apriori(basket_set_United_Kingdom , min_support= 0.06 , use_colnames= True)
frequent_items_United_Kingdom.head(10)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/mlxtend/frequent_patterns/fpcommon.py:110: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#     support                             itemsets
# 0  0.073445      (ASSORTED COLOUR BIRD ORNAMENT)
# 1  0.062356              (HEART OF WICKER SMALL)
# 2  0.062088            (JUMBO BAG PINK POLKADOT)
# 3  0.103820            (JUMBO BAG RED RETROSPOT)
# 4  0.060695  (JUMBO SHOPPER VINTAGE RED PAISLEY)
# 5  0.060535             (JUMBO STORAGE BAG SUKI)
# 6  0.065142            (LUNCH BAG  BLACK SKULL.)
# 7  0.074570            (LUNCH BAG RED RETROSPOT)
# 8  0.065302     (NATURAL SLATE HEART CHALKBOARD)
# 9  0.060481    (PACK OF 72 RETROSPOT CAKE CASES)

# %%
basket_set_France = basket_France.applymap(encode_units)
frequent_items_France = apriori(basket_set_France , min_support= 0.07 , use_colnames= True)
frequent_items_France.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/mlxtend/frequent_patterns/fpcommon.py:110: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#     support                        itemsets
# 0  0.071429   (4 TRADITIONAL SPINNING TOPS)
# 1  0.096939    (ALARM CLOCK BAKELIKE GREEN)
# 2  0.102041     (ALARM CLOCK BAKELIKE PINK)
# 3  0.094388      (ALARM CLOCK BAKELIKE RED)
# 4  0.081633  (BAKING SET 9 PIECE RETROSPOT)

# %%
basket_set_Netherlands = basket_Netherlands.applymap(encode_units)
frequent_items_Netherlands = apriori(basket_set_Netherlands , min_support= 0.07 , use_colnames= True)
frequent_items_Netherlands.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/mlxtend/frequent_patterns/fpcommon.py:110: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#     support                             itemsets
# 0  0.073684         (3 HOOK HANGER MAGIC GARDEN)
# 1  0.073684           (36 FOIL HEART CAKE CASES)
# 2  0.073684  (5 HOOK HANGER RED MAGIC TOADSTOOL)
# 3  0.105263     (72 SWEETHEART FAIRY CAKE CASES)
# 4  0.073684         (BREAD BIN DINER STYLE PINK)

# %%
basket_set_Spain = basket_Spain.applymap(encode_units)
frequent_items_Spain = apriori(basket_set_Spain , min_support= 0.07 , use_colnames= True)
frequent_items_Spain.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/mlxtend/frequent_patterns/fpcommon.py:110: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#     support                               itemsets
# 0  0.166667               (6 RIBBONS RUSTIC CHARM)
# 1  0.077778           (ALARM CLOCK BAKELIKE GREEN)
# 2  0.133333        (ASSORTED COLOUR BIRD ORNAMENT)
# 3  0.111111  (CLASSIC METAL BIRDCAGE PLANT HOLDER)
# 4  0.100000                 (DOLLY GIRL LUNCH BOX)

# %%
rules_Germany = association_rules(frequent_items_Germany, metric='lift',min_threshold= 1)
best_rules_Germany = rules_Germany[(rules_Germany['lift'] >= 0.6) & (rules_Germany['confidence'] >= 0.6)]
best_rules_Germany.sort_values(by='confidence', ascending=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                           antecedents  \
# 16                (ROUND SNACK BOXES SET OF 4 FRUITS)
# 28  (ROUND SNACK BOXES SET OF4 WOODLAND, ROUND SNA...
# 6                          (PLASTERS IN TIN SPACEBOY)
# 18               (ROUND SNACK BOXES SET OF4 WOODLAND)
# 23                           (WOODLAND CHARLOTTE BAG)
# 1                            (6 RIBBONS RUSTIC CHARM)
# 20                               (SPACEBOY LUNCH BOX)
# 15                         (REGENCY CAKESTAND 3 TIER)
# 2                        (JUMBO BAG WOODLAND ANIMALS)
# 4                     (PLASTERS IN TIN CIRCUS PARADE)
# 8                  (PLASTERS IN TIN WOODLAND ANIMALS)
# 13                    (RED TOADSTOOL LED NIGHT LIGHT)
# 25                (ROUND SNACK BOXES SET OF 4 FRUITS)
# 30       (ROUND SNACK BOXES SET OF 4 FRUITS, POSTAGE)
# 32                (ROUND SNACK BOXES SET OF 4 FRUITS)
# 26                               (SPACEBOY LUNCH BOX)
#
#                                       consequents  antecedent support  \
# 16                                      (POSTAGE)            0.157549
# 28                                      (POSTAGE)            0.131291
# 6                                       (POSTAGE)            0.107221
# 18                                      (POSTAGE)            0.245077
# 23                                      (POSTAGE)            0.126915
# 1                                       (POSTAGE)            0.102845
# 20                                      (POSTAGE)            0.102845
# 15                                      (POSTAGE)            0.137856
# 2                                       (POSTAGE)            0.100656
# 4                                       (POSTAGE)            0.115974
# 8                                       (POSTAGE)            0.137856
# 13                                      (POSTAGE)            0.096280
# 25           (ROUND SNACK BOXES SET OF4 WOODLAND)            0.157549
# 30           (ROUND SNACK BOXES SET OF4 WOODLAND)            0.150985
# 32  (ROUND SNACK BOXES SET OF4 WOODLAND, POSTAGE)            0.157549
# 26           (ROUND SNACK BOXES SET OF4 WOODLAND)            0.102845
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 16            0.818381  0.150985    0.958333  1.171012  0.022049    4.358862
# 28            0.818381  0.124726    0.950000  1.160829  0.017280    3.632385
# 6             0.818381  0.100656    0.938776  1.147113  0.012909    2.966448
# 18            0.818381  0.225383    0.919643  1.123735  0.024817    2.260151
# 23            0.818381  0.115974    0.913793  1.116587  0.012109    2.106783
# 1             0.818381  0.091904    0.893617  1.091933  0.007738    1.707221
# 20            0.818381  0.091904    0.893617  1.091933  0.007738    1.707221
# 15            0.818381  0.120350    0.873016  1.066760  0.007532    1.430252
# 2             0.818381  0.087527    0.869565  1.062544  0.005152    1.392414
# 4             0.818381  0.100656    0.867925  1.060539  0.005746    1.375117
# 8             0.818381  0.118162    0.857143  1.047364  0.005344    1.271335
# 13            0.818381  0.080963    0.840909  1.027528  0.002169    1.141607
# 25            0.245077  0.131291    0.833333  3.400298  0.092679    4.529540
# 30            0.245077  0.124726    0.826087  3.370730  0.087724    4.340810
# 32            0.225383  0.124726    0.791667  3.512540  0.089218    3.718162
# 26            0.245077  0.070022    0.680851  2.778116  0.044817    2.365427
#
#     zhangs_metric
# 16       0.173348
# 28       0.159486
# 6        0.143649
# 18       0.145856
# 23       0.119591
# 1        0.093844
# 20       0.093844
# 15       0.072589
# 2        0.065450
# 4        0.064572
# 8        0.052453
# 13       0.029645
# 25       0.837922
# 30       0.828405
# 32       0.849077
# 26       0.713415

# %%
rules_United_Kingdom = association_rules(frequent_items_United_Kingdom, metric='lift',min_threshold= 1)
#best_rules_United_Kingdom = rules_United_Kingdom[(rules_United_Kingdom['lift'] >= 0.5) & (rules_United_Kingdom['confidence'] >= 0.5)]
#best_rules_United_Kingdom.sort_values(by='confidence', ascending=False)
rules_United_Kingdom
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction, zhangs_metric]
# Index: []

# %%
rules_France = association_rules(frequent_items_France, metric='lift',min_threshold= 1)
best_rules_France = rules_France[(rules_France['lift'] >= 0.6) & (rules_France['confidence'] >= 0.6)]
best_rules_France.sort_values(by='confidence', ascending=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                            antecedents  \
# 16                        (JUMBO BAG WOODLAND ANIMALS)
# 121  (SET/6 RED SPOTTY PAPER CUPS, SET/20 RED RETRO...
# 122  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 128  (SET/6 RED SPOTTY PAPER CUPS, POSTAGE, SET/20 ...
# 129  (SET/20 RED RETROSPOT PAPER NAPKINS, POSTAGE, ...
# ..                                                 ...
# 105                      (SET/6 RED SPOTTY PAPER CUPS)
# 91         (PLASTERS IN TIN WOODLAND ANIMALS, POSTAGE)
# 97         (PLASTERS IN TIN WOODLAND ANIMALS, POSTAGE)
# 100                         (PLASTERS IN TIN SPACEBOY)
# 37                     (PLASTERS IN TIN CIRCUS PARADE)
#
#                                        consequents  antecedent support  \
# 16                                       (POSTAGE)            0.076531
# 121                (SET/6 RED SPOTTY PAPER PLATES)            0.102041
# 122                  (SET/6 RED SPOTTY PAPER CUPS)            0.102041
# 128                (SET/6 RED SPOTTY PAPER PLATES)            0.084184
# 129                  (SET/6 RED SPOTTY PAPER CUPS)            0.084184
# ..                                             ...                 ...
# 105  (POSTAGE, SET/20 RED RETROSPOT PAPER NAPKINS)            0.137755
# 91                 (PLASTERS IN TIN CIRCUS PARADE)            0.137755
# 97                      (PLASTERS IN TIN SPACEBOY)            0.137755
# 100    (PLASTERS IN TIN WOODLAND ANIMALS, POSTAGE)            0.137755
# 37              (PLASTERS IN TIN WOODLAND ANIMALS)            0.168367
#
#      consequent support   support  confidence      lift  leverage  conviction  \
# 16             0.765306  0.076531    1.000000  1.306667  0.017961         inf
# 121            0.127551  0.099490    0.975000  7.644000  0.086474   34.897959
# 122            0.137755  0.099490    0.975000  7.077778  0.085433   34.489796
# 128            0.127551  0.081633    0.969697  7.602424  0.070895   28.790816
# 129            0.137755  0.081633    0.969697  7.039282  0.070036   28.454082
# ..                  ...       ...         ...       ...       ...         ...
# 105            0.109694  0.084184    0.611111  5.571059  0.069073    2.289359
# 91             0.168367  0.084184    0.611111  3.629630  0.060990    2.138484
# 97             0.137755  0.084184    0.611111  4.436214  0.065207    2.217201
# 100            0.137755  0.084184    0.611111  4.436214  0.065207    2.217201
# 37             0.170918  0.102041    0.606061  3.545907  0.073264    2.104592
#
#      zhangs_metric
# 16        0.254144
# 121       0.967949
# 122       0.956294
# 128       0.948294
# 129       0.936804
# ..             ...
# 105       0.951587
# 91        0.840237
# 97        0.898332
# 100       0.898332
# 37        0.863344
#
# [92 rows x 10 columns]

# %%
rules_Netherlands = association_rules(frequent_items_Netherlands, metric='lift',min_threshold= 1)
best_rules_Netherlands = rules_Netherlands[(rules_Netherlands['lift'] >= 0.6) & (rules_Netherlands['confidence'] >= 0.6)]
best_rules_Netherlands.sort_values(by='confidence', ascending=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                             antecedents  \
# 1365  (DOLLY GIRL LUNCH BOX, PLASTERS IN TIN VINTAGE...
# 813   (LUNCH BAG RED RETROSPOT, RED TOADSTOOL LED NI...
# 808   (LUNCH BAG RED RETROSPOT, SPACEBOY BIRTHDAY CARD)
# 806   (PLASTERS IN TIN SPACEBOY, LUNCH BAG RED RETRO...
# 1609  (LUNCH BOX WITH CUTLERY RETROSPOT, ROUND SNACK...
# ...                                                 ...
# 1400  (SPACEBOY LUNCH BOX, DOLLY GIRL LUNCH BOX, ROU...
# 1130  (ROUND SNACK BOXES SET OF4 WOODLAND, ROUND SNA...
# 1148  (ROUND SNACK BOXES SET OF4 WOODLAND, ROUND SNA...
# 304                (ROUND SNACK BOXES SET OF4 WOODLAND)
# 637                (ROUND SNACK BOXES SET OF4 WOODLAND)
#
#                                             consequents  antecedent support  \
# 1365  (ROUND SNACK BOXES SET OF4 WOODLAND, RED RETRO...            0.073684
# 813                            (WOODLAND CHARLOTTE BAG)            0.073684
# 808                          (PLASTERS IN TIN SPACEBOY)            0.084211
# 806                            (SPACEBOY BIRTHDAY CARD)            0.084211
# 1609               (ROUND SNACK BOXES SET OF4 WOODLAND)            0.073684
# ...                                                 ...                 ...
# 1400                      (RED RETROSPOT CHARLOTTE BAG)            0.157895
# 1130                           (SPACEBOY BIRTHDAY CARD)            0.157895
# 1148                           (WOODLAND CHARLOTTE BAG)            0.157895
# 304                 (ROUND SNACK BOXES SET OF 4 FRUITS)            0.263158
# 637          (SPACEBOY LUNCH BOX, DOLLY GIRL LUNCH BOX)            0.263158
#
#       consequent support   support  confidence      lift  leverage  \
# 1365            0.115789  0.073684         1.0  8.636364  0.065152
# 813             0.168421  0.073684         1.0  5.937500  0.061274
# 808             0.126316  0.084211         1.0  7.916667  0.073573
# 806             0.178947  0.084211         1.0  5.588235  0.069141
# 1609            0.263158  0.073684         1.0  3.800000  0.054294
# ...                  ...       ...         ...       ...       ...
# 1400            0.126316  0.094737         0.6  4.750000  0.074792
# 1130            0.178947  0.094737         0.6  3.352941  0.066482
# 1148            0.168421  0.094737         0.6  3.562500  0.068144
# 304             0.178947  0.157895         0.6  3.352941  0.110803
# 637             0.221053  0.157895         0.6  2.714286  0.099723
#
#       conviction  zhangs_metric
# 1365         inf       0.954545
# 813          inf       0.897727
# 808          inf       0.954023
# 806          inf       0.896552
# 1609         inf       0.795455
# ...          ...            ...
# 1400    2.184211       0.937500
# 1130    2.052632       0.833333
# 1148    2.078947       0.854167
# 304     2.052632       0.952381
# 637     1.947368       0.857143
#
# [989 rows x 10 columns]

# %%
rules_Spain = association_rules(frequent_items_Spain, metric='lift',min_threshold= 1)
best_rules_Spain = rules_Spain[(rules_Spain['lift'] >= 0.6) & (rules_Spain['confidence'] >= 0.6)]
best_rules_Spain.sort_values(by='confidence', ascending=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                           antecedents  \
# 15                        (POPPY'S PLAYHOUSE KITCHEN)
# 9                    (DOORMAT SPOTTY HOME SWEET HOME)
# 11                  (PACK OF 72 RETROSPOT CAKE CASES)
# 26  (6 RIBBONS RUSTIC CHARM, ASSORTED COLOUR BIRD ...
# 5                     (ASSORTED COLOUR BIRD ORNAMENT)
# 6               (CLASSIC METAL BIRDCAGE PLANT HOLDER)
# 23               (SET/20 RED RETROSPOT PAPER NAPKINS)
# 14                        (POPPY'S PLAYHOUSE BEDROOM)
# 16                        (POPPY'S PLAYHOUSE BEDROOM)
# 3                            (6 RIBBONS RUSTIC CHARM)
# 25           (POSTAGE, ASSORTED COLOUR BIRD ORNAMENT)
# 12                           (PLASTERS IN TIN SKULLS)
# 20               (SET OF 72 RETROSPOT PAPER  DOILIES)
# 19                         (REGENCY CAKESTAND 3 TIER)
# 29                    (ASSORTED COLOUR BIRD ORNAMENT)
# 1                     (ASSORTED COLOUR BIRD ORNAMENT)
# 24                  (POSTAGE, 6 RIBBONS RUSTIC CHARM)
# 28                           (6 RIBBONS RUSTIC CHARM)
# 0                            (6 RIBBONS RUSTIC CHARM)
#
#                                  consequents  antecedent support  \
# 15               (POPPY'S PLAYHOUSE BEDROOM)            0.077778
# 9                                  (POSTAGE)            0.077778
# 11                                 (POSTAGE)            0.122222
# 26                                 (POSTAGE)            0.100000
# 5                                  (POSTAGE)            0.133333
# 6                                  (POSTAGE)            0.111111
# 23                                 (POSTAGE)            0.100000
# 14               (POPPY'S PLAYHOUSE KITCHEN)            0.088889
# 16                                 (POSTAGE)            0.088889
# 3                                  (POSTAGE)            0.166667
# 25                  (6 RIBBONS RUSTIC CHARM)            0.122222
# 12                                 (POSTAGE)            0.111111
# 20                                 (POSTAGE)            0.111111
# 19                                 (POSTAGE)            0.244444
# 29         (POSTAGE, 6 RIBBONS RUSTIC CHARM)            0.133333
# 1                   (6 RIBBONS RUSTIC CHARM)            0.133333
# 24           (ASSORTED COLOUR BIRD ORNAMENT)            0.144444
# 28  (POSTAGE, ASSORTED COLOUR BIRD ORNAMENT)            0.166667
# 0            (ASSORTED COLOUR BIRD ORNAMENT)            0.166667
#
#     consequent support   support  confidence       lift  leverage  conviction  \
# 15            0.088889  0.077778    1.000000  11.250000  0.070864         inf
# 9             0.688889  0.077778    1.000000   1.451613  0.024198         inf
# 11            0.688889  0.122222    1.000000   1.451613  0.038025         inf
# 26            0.688889  0.100000    1.000000   1.451613  0.031111         inf
# 5             0.688889  0.122222    0.916667   1.330645  0.030370    3.733333
# 6             0.688889  0.100000    0.900000   1.306452  0.023457    3.111111
# 23            0.688889  0.088889    0.888889   1.290323  0.020000    2.800000
# 14            0.077778  0.077778    0.875000  11.250000  0.070864    7.377778
# 16            0.688889  0.077778    0.875000   1.270161  0.016543    2.488889
# 3             0.688889  0.144444    0.866667   1.258065  0.029630    2.333333
# 25            0.166667  0.100000    0.818182   4.909091  0.079630    4.583333
# 12            0.688889  0.088889    0.800000   1.161290  0.012346    1.555556
# 20            0.688889  0.088889    0.800000   1.161290  0.012346    1.555556
# 19            0.688889  0.188889    0.772727   1.121701  0.020494    1.368889
# 29            0.144444  0.100000    0.750000   5.192308  0.080741    3.422222
# 1             0.166667  0.100000    0.750000   4.500000  0.077778    3.333333
# 24            0.133333  0.100000    0.692308   5.192308  0.080741    2.816667
# 28            0.122222  0.100000    0.600000   4.909091  0.079630    2.194444
# 0             0.133333  0.100000    0.600000   4.500000  0.077778    2.166667
#
#     zhangs_metric
# 15       0.987952
# 9        0.337349
# 11       0.354430
# 26       0.345679
# 5        0.286713
# 6        0.263889
# 23       0.250000
# 14       1.000000
# 16       0.233449
# 3        0.246154
# 25       0.907173
# 12       0.156250
# 20       0.156250
# 19       0.143599
# 29       0.931624
# 1        0.897436
# 24       0.943723
# 28       0.955556
# 0        0.933333
